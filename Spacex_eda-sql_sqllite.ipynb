# %% [markdown]
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlserver
# Out:
# Requirement already satisfied: sqlserver in c:\users\warad\anaconda3\lib\site-packages (0.0.17.1)
# Requirement already satisfied: pyodbc in c:\users\warad\anaconda3\lib\site-packages (from sqlserver) (4.0.34)
# Requirement already satisfied: pandas in c:\users\warad\anaconda3\lib\site-packages (from sqlserver) (2.1.4)
# Requirement already satisfied: lxml in c:\users\warad\anaconda3\lib\site-packages (from sqlserver) (4.9.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\warad\anaconda3\lib\site-packages (from pandas->sqlserver) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\warad\anaconda3\lib\site-packages (from pandas->sqlserver) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\warad\anaconda3\lib\site-packages (from pandas->sqlserver) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\warad\anaconda3\lib\site-packages (from pandas->sqlserver) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\warad\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->sqlserver) (1.16.0)

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
#Please uncomment and execute the code below if you are working locally.

# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\warad\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\warad\anaconda3\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\warad\anaconda3\lib\site-packages (from ipython-sql) (8.15.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\warad\anaconda3\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\warad\anaconda3\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\users\warad\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\warad\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\warad\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\warad\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (2.0.1)
# Requirement already satisfied: backcall in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: colorama in c:\users\warad\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\warad\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\warad\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\warad\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\warad\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\warad\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)

# %%
# %load_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) table SPACEXTABLE already exists
# [SQL: create table SPACEXTABLE as select * from SPACEXTBL where Date is not null]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
unique_launch_sites = df['Launch_Site'].unique()
print(unique_launch_sites)
# Out:
# ['CCAFS LC-40' 'VAFB SLC-4E' 'KSC LC-39A' 'CCAFS SLC-40']

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
df.head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success           No attempt
# 3  LEO (ISS)       NASA (CRS)         Success           No attempt
# 4  LEO (ISS)       NASA (CRS)         Success           No attempt

# %%
df.columns
# Out:
# Index(['Date', 'Time (UTC)', 'Booster_Version', 'Launch_Site', 'Payload',
#        'PAYLOAD_MASS__KG_', 'Orbit', 'Customer', 'Mission_Outcome',
#        'Landing_Outcome'],
#       dtype='object')

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
sum_payload_mass = df[df['Customer'] == 'NASA (CRS)']['PAYLOAD_MASS__KG_'].sum()
print(sum_payload_mass)
# Out:
# 45596

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
df[df['Booster_Version']=='F9 v1.1']['PAYLOAD_MASS__KG_'].mean()
# Out:
# 2928.4

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
df.columns
# Out:
# Index(['Date', 'Time (UTC)', 'Booster_Version', 'Launch_Site', 'Payload',
#        'PAYLOAD_MASS__KG_', 'Orbit', 'Customer', 'Mission_Outcome',
#        'Landing_Outcome'],
#       dtype='object')

# %%
df.head(50)
# Out:
#           Date Time (UTC) Booster_Version   Launch_Site  \
# 0   2010-06-04   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1   2010-12-08   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2   2012-05-22    7:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3   2012-10-08    0:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4   2013-03-01   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# 5   2013-09-29   16:00:00  F9 v1.1  B1003   VAFB SLC-4E
# 6   2013-12-03   22:41:00         F9 v1.1   CCAFS LC-40
# 7   2014-01-06   22:06:00         F9 v1.1   CCAFS LC-40
# 8   2014-04-18   19:25:00         F9 v1.1   CCAFS LC-40
# 9   2014-07-14   15:15:00         F9 v1.1   CCAFS LC-40
# 10  2014-08-05    8:00:00         F9 v1.1   CCAFS LC-40
# 11  2014-09-07    5:00:00   F9 v1.1 B1011   CCAFS LC-40
# 12  2014-09-21    5:52:00   F9 v1.1 B1010   CCAFS LC-40
# 13  2015-01-10    9:47:00   F9 v1.1 B1012   CCAFS LC-40
# 14  2015-02-11   23:03:00   F9 v1.1 B1013   CCAFS LC-40
# 15  2015-03-02    3:50:00   F9 v1.1 B1014   CCAFS LC-40
# 16  2015-04-14   20:10:00   F9 v1.1 B1015   CCAFS LC-40
# 17  2015-04-27   23:03:00   F9 v1.1 B1016   CCAFS LC-40
# 18  2015-06-28   14:21:00   F9 v1.1 B1018   CCAFS LC-40
# 19  2015-12-22    1:29:00     F9 FT B1019   CCAFS LC-40
# 20  2016-01-17   18:42:00   F9 v1.1 B1017   VAFB SLC-4E
# 21  2016-03-04   23:35:00     F9 FT B1020   CCAFS LC-40
# 22  2016-04-08   20:43:00   F9 FT B1021.1   CCAFS LC-40
# 23  2016-05-06    5:21:00     F9 FT B1022   CCAFS LC-40
# 24  2016-05-27   21:39:00   F9 FT B1023.1   CCAFS LC-40
# 25  2016-06-15   14:29:00     F9 FT B1024   CCAFS LC-40
# 26  2016-07-18    4:45:00   F9 FT B1025.1   CCAFS LC-40
# 27  2016-08-14    5:26:00     F9 FT B1026   CCAFS LC-40
# 28  2017-01-14   17:54:00   F9 FT B1029.1   VAFB SLC-4E
# 29  2017-02-19   14:39:00   F9 FT B1031.1    KSC LC-39A
# 30  2017-03-16    6:00:00     F9 FT B1030    KSC LC-39A
# 31  2017-03-30   22:27:00  F9 FT  B1021.2    KSC LC-39A
# 32  2017-05-01   11:15:00   F9 FT B1032.1    KSC LC-39A
# 33  2017-05-15   23:21:00     F9 FT B1034    KSC LC-39A
# 34  2017-06-03   21:07:00   F9 FT B1035.1    KSC LC-39A
# 35  2017-06-23   19:10:00  F9 FT  B1029.2    KSC LC-39A
# 36  2017-06-25   20:25:00   F9 FT B1036.1   VAFB SLC-4E
# 37  2017-07-05   23:38:00     F9 FT B1037    KSC LC-39A
# 38  2017-08-14   16:31:00   F9 B4 B1039.1    KSC LC-39A
# 39  2017-08-24   18:51:00   F9 FT B1038.1   VAFB SLC-4E
# 40  2017-09-07   14:00:00   F9 B4 B1040.1    KSC LC-39A
# 41  2017-10-09   12:37:00   F9 B4 B1041.1   VAFB SLC-4E
# 42  2017-10-11   22:53:00  F9 FT  B1031.2    KSC LC-39A
# 43  2017-10-30   19:34:00   F9 B4 B1042.1    KSC LC-39A
# 44  2017-12-15   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 45  2017-12-23    1:27:00  F9 FT  B1036.2   VAFB SLC-4E
# 46  2018-01-08    1:00:00   F9 B4 B1043.1  CCAFS SLC-40
# 47  2018-01-31   21:25:00  F9 FT  B1032.2  CCAFS SLC-40
# 48  2018-02-22   14:17:00  F9 FT  B1038.2   VAFB SLC-4E
# 49  2018-03-06    5:33:00     F9 B4 B1044  CCAFS SLC-40
#
#                                               Payload  PAYLOAD_MASS__KG_  \
# 0                Dragon Spacecraft Qualification Unit                  0
# 1   Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                               Dragon demo flight C2                525
# 3                                        SpaceX CRS-1                500
# 4                                        SpaceX CRS-2                677
# 5                                            CASSIOPE                500
# 6                                               SES-8               3170
# 7                                           Thaicom 6               3325
# 8                                        SpaceX CRS-3               2296
# 9             OG2 Mission 1  6 Orbcomm-OG2 satellites               1316
# 10                                          AsiaSat 8               4535
# 11                                          AsiaSat 6               4428
# 12                                       SpaceX CRS-4               2216
# 13                                       SpaceX CRS-5               2395
# 14                                             DSCOVR                570
# 15                         ABS-3A Eutelsat 115 West B               4159
# 16                                       SpaceX CRS-6               1898
# 17                             Turkmen 52 / MonacoSAT               4707
# 18                                       SpaceX CRS-7               1952
# 19           OG2 Mission 2  11 Orbcomm-OG2 satellites               2034
# 20                                            Jason-3                553
# 21                                              SES-9               5271
# 22                                       SpaceX CRS-8               3136
# 23                                           JCSAT-14               4696
# 24                                          Thaicom 8               3100
# 25                         ABS-2A Eutelsat 117 West B               3600
# 26                                       SpaceX CRS-9               2257
# 27                                           JCSAT-16               4600
# 28                                     Iridium NEXT 1               9600
# 29                                      SpaceX CRS-10               2490
# 30                                        EchoStar 23               5600
# 31                                             SES-10               5300
# 32                                            NROL-76               5300
# 33                                      Inmarsat-5 F4               6070
# 34                                      SpaceX CRS-11               2708
# 35                                      BulgariaSat-1               3669
# 36                                     Iridium NEXT 2               9600
# 37                                       Intelsat 35e               6761
# 38                                      SpaceX CRS-12               3310
# 39                                         Formosat-5                475
# 40                                 Boeing X-37B OTV-5               4990
# 41                                     Iridium NEXT 3               9600
# 42                              SES-11 / EchoStar 105               5200
# 43                                        Koreasat 5A               3500
# 44                                      SpaceX CRS-13               2205
# 45                                     Iridium NEXT 4               9600
# 46                                               Zuma               5000
# 47                                  GovSat-1 / SES-16               4230
# 48                                  Paz  Tintin A & B               2150
# 49                             Hispasat 30W-6  PODSat               6092
#
#         Orbit                            Customer  \
# 0         LEO                              SpaceX
# 1   LEO (ISS)                     NASA (COTS) NRO
# 2   LEO (ISS)                         NASA (COTS)
# 3   LEO (ISS)                          NASA (CRS)
# 4   LEO (ISS)                          NASA (CRS)
# 5   Polar LEO                                 MDA
# 6         GTO                                 SES
# 7         GTO                             Thaicom
# 8   LEO (ISS)                          NASA (CRS)
# 9         LEO                             Orbcomm
# 10        GTO                             AsiaSat
# 11        GTO                             AsiaSat
# 12  LEO (ISS)                          NASA (CRS)
# 13  LEO (ISS)                          NASA (CRS)
# 14        HEO            U.S. Air Force NASA NOAA
# 15        GTO                        ABS Eutelsat
# 16  LEO (ISS)                          NASA (CRS)
# 17        GTO  Turkmenistan National Space Agency
# 18  LEO (ISS)                          NASA (CRS)
# 19        LEO                             Orbcomm
# 20        LEO                NASA (LSP) NOAA CNES
# 21        GTO                                 SES
# 22  LEO (ISS)                          NASA (CRS)
# 23        GTO              SKY Perfect JSAT Group
# 24        GTO                             Thaicom
# 25        GTO                        ABS Eutelsat
# 26  LEO (ISS)                          NASA (CRS)
# 27        GTO              SKY Perfect JSAT Group
# 28  Polar LEO              Iridium Communications
# 29  LEO (ISS)                          NASA (CRS)
# 30        GTO                            EchoStar
# 31        GTO                                 SES
# 32        LEO                                 NRO
# 33        GTO                            Inmarsat
# 34  LEO (ISS)                          NASA (CRS)
# 35        GTO                           Bulsatcom
# 36        LEO              Iridium Communications
# 37        GTO                            Intelsat
# 38  LEO (ISS)                          NASA (CRS)
# 39        SSO                                NSPO
# 40        LEO                      U.S. Air Force
# 41  Polar LEO              Iridium Communications
# 42        GTO                        SES EchoStar
# 43        GTO                      KT Corporation
# 44  LEO (ISS)                          NASA (CRS)
# 45  Polar LEO              Iridium Communications
# 46        LEO                    Northrop Grumman
# 47        GTO                                 SES
# 48        SSO          Hisdesat exactEarth SpaceX
# 49        GTO                 Hispasat  NovaWurks
#
#                      Mission_Outcome         Landing_Outcome
# 0                            Success     Failure (parachute)
# 1                            Success     Failure (parachute)
# 2                            Success              No attempt
# 3                            Success              No attempt
# 4                            Success              No attempt
# 5                            Success    Uncontrolled (ocean)
# 6                            Success              No attempt
# 7                            Success              No attempt
# 8                            Success      Controlled (ocean)
# 9                            Success      Controlled (ocean)
# 10                           Success              No attempt
# 11                           Success              No attempt
# 12                           Success    Uncontrolled (ocean)
# 13                           Success    Failure (drone ship)
# 14                           Success      Controlled (ocean)
# 15                           Success              No attempt
# 16                           Success    Failure (drone ship)
# 17                           Success              No attempt
# 18               Failure (in flight)  Precluded (drone ship)
# 19                           Success    Success (ground pad)
# 20                           Success    Failure (drone ship)
# 21                           Success    Failure (drone ship)
# 22                           Success    Success (drone ship)
# 23                           Success    Success (drone ship)
# 24                           Success    Success (drone ship)
# 25                           Success    Failure (drone ship)
# 26                           Success    Success (ground pad)
# 27                           Success    Success (drone ship)
# 28                           Success    Success (drone ship)
# 29                           Success    Success (ground pad)
# 30                           Success              No attempt
# 31                           Success    Success (drone ship)
# 32                           Success    Success (ground pad)
# 33                           Success              No attempt
# 34                           Success    Success (ground pad)
# 35                           Success    Success (drone ship)
# 36                           Success    Success (drone ship)
# 37                           Success              No attempt
# 38                           Success    Success (ground pad)
# 39                           Success    Success (drone ship)
# 40                           Success    Success (ground pad)
# 41                           Success    Success (drone ship)
# 42                           Success    Success (drone ship)
# 43                           Success    Success (drone ship)
# 44                           Success    Success (ground pad)
# 45                           Success      Controlled (ocean)
# 46  Success (payload status unclear)    Success (ground pad)
# 47                           Success      Controlled (ocean)
# 48                           Success              No attempt
# 49                           Success              No attempt

# %%
df[df['Landing_Outcome']== 'Success (ground pad)']['Date'].min()
# Out:
# '2015-12-22'

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
df[df['Landing_Outcome']=='Success (drone ship)' & (df['PAYLOAD_MASS__KG_']>4000 & df['PAYLOAD_MASS__KG_']<6000)]['Booster_Version']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10452\1980107532.py in ?()
# ----> 1 df[df['Landing_Outcome']=='Success (drone ship)' & (df['PAYLOAD_MASS__KG_']>4000 & df['PAYLOAD_MASS__KG_']<6000)]['Booster_Version']
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
filtered_df = df[(df['Landing_Outcome'] == 'Success (drone ship)') & (df['PAYLOAD_MASS__KG_'] > 4000) & (df['PAYLOAD_MASS__KG_'] < 6000)]['Booster_Version']
print(filtered_df)
# Out:
# 23       F9 FT B1022
# 27       F9 FT B1026
# 31    F9 FT  B1021.2
# 42    F9 FT  B1031.2
# Name: Booster_Version, dtype: object

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
df['Mission_Outcome'].value_counts().reset_index()
# Out:
#                     Mission_Outcome  count
# 0                           Success     98
# 1               Failure (in flight)      1
# 2  Success (payload status unclear)      1
# 3                          Success       1

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
df.head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success           No attempt
# 3  LEO (ISS)       NASA (CRS)         Success           No attempt
# 4  LEO (ISS)       NASA (CRS)         Success           No attempt

# %%
# Find the maximum payload mass
max_payload_mass = df['PAYLOAD_MASS__KG_'].max()

# Find the booster versions which have carried the maximum payload mass
max_payload_df = df[df['PAYLOAD_MASS__KG_'] == max_payload_mass][['Booster_Version', 'PAYLOAD_MASS__KG_']]

# Print the maximum payload mass and the booster versions with their respective payload masses
print("Maximum Payload Mass: ", max_payload_mass)
print("Booster Versions with their respective payload masses: ")
print(max_payload_df)
# Out:
# Maximum Payload Mass:  15600
# Booster Versions with their respective payload masses:
#    Booster_Version  PAYLOAD_MASS__KG_
# 74   F9 B5 B1048.4              15600
# 77   F9 B5 B1049.4              15600
# 79   F9 B5 B1051.3              15600
# 80   F9 B5 B1056.4              15600
# 82   F9 B5 B1048.5              15600
# 83   F9 B5 B1051.4              15600
# 85   F9 B5 B1049.5              15600
# 92  F9 B5 B1060.2               15600
# 93  F9 B5 B1058.3               15600
# 94   F9 B5 B1051.6              15600
# 95   F9 B5 B1060.3              15600
# 99  F9 B5 B1049.7               15600

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
# Convert the date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Filter the DataFrame for the year 2015 and failure landing outcomes in a drone ship
filtered_df = df[(df['Date'].dt.year == 2015) & (df['Landing_Outcome'] == 'Failure (drone ship)')]

# Create a new column for the month name
filtered_df['Month'] = filtered_df['Date'].dt.month_name()

# Select the required columns
result = filtered_df[['Month', 'Booster_Version', 'Launch_Site']]

# Print the result
print(result)
# Out:
#       Month Booster_Version  Launch_Site
# 13  January   F9 v1.1 B1012  CCAFS LC-40
# 16    April   F9 v1.1 B1015  CCAFS LC-40
# C:\Users\warad\AppData\Local\Temp\ipykernel_10452\19310773.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Month'] = filtered_df['Date'].dt.month_name()

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
# Convert the date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Filter the DataFrame for the specified date range
filtered_df = df[(df['Date'] >= '2010-06-04') & (df['Date'] <= '2017-03-20')]

# Get the count of each landing outcome
landing_outcome_counts = filtered_df['Landing_Outcome'].value_counts()

# Sort the counts in descending order
sorted_counts = landing_outcome_counts.sort_values(ascending=False)

# Print the sorted counts
print(sorted_counts)
# Out:
# Landing_Outcome
# No attempt                10
# Failure (drone ship)       5
# Success (drone ship)       5
# Controlled (ocean)         3
# Success (ground pad)       3
# Failure (parachute)        2
# Uncontrolled (ocean)       2
# Precluded (drone ship)     1
# Name: count, dtype: int64

# %% [markdown]
# ## Author
#
# <h4> Tushar Warade </h4>
